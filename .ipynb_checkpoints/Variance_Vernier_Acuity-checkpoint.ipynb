# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set up files
mydir = 'data/vernierSixBlocksData/first_second_Runs_sixBlocks'
files = [f for f in os.listdir(mydir) if f.endswith('.csv')]

numSubj = len(files)
print('Number of subjects: ', numSubj)
# Out:
# Number of subjects:  15

# %%
# Initialize variables
eccentricity = 8
numRepeats = 6
block_start = 2                            # excluding the first block
block_end = block_start + numRepeats - 1   # the last block
num_staircase_per_block = 2
num_trials_per_staircase = 35
subj_left = np.full((numSubj, numRepeats), np.nan)
subj_right = np.full((numSubj, numRepeats), np.nan)


print('Shape of left thresholds matrix:', subj_left.shape)
print('Shape of right thresholds matrix:', subj_right.shape)
# Out:
# Shape of left thresholds matrix: (15, 6)
# Shape of right thresholds matrix: (15, 6)

# %%
# Calculate thresholds
for subj in range(numSubj):
    # Read the CSV file
    file_path = os.path.join(mydir, files[subj])
    mainOutput = pd.read_csv(file_path)
    
    # Exclusion criteria 1: experiment completed
    complete_val = mainOutput['experimentCompleteBool'].dropna().iloc[0]  # Get the non-NaN value
    complete_bool = str(complete_val) == 'True'
    
    
    for b in range(block_start, block_end + 1):  # Loop over blocks
        for s in range(num_staircase_per_block):  # Loop over staircases

            blockOfInterest = b
            staircase = s + 1

            # Filter rows based on block and staircase
            staircase = mainOutput['staircaseName'].fillna('').str.contains(f'{blockOfInterest}_{staircase}')
            rows_staircase = mainOutput[staircase]

            # Exclusion criteria 2: number of trials sent to quest
            # Count trials sent to quest
            trial_sent = rows_staircase['trialGivenToQuest']
            num_trial_sent = sum(str(this_trial) == 'True' for this_trial in trial_sent)
            trial_sent_bool = num_trial_sent >= num_trials_per_staircase
            
            
            # Exclusion criteria 3: questSD < 0.1
            # questSD = rows_staircase['questSDAtEndOfTrialsLoop'].dropna().iloc[0]
            # small_questSD_bool = questSD < 0.1
            
            # Process thresholds
            if complete_bool & trial_sent_bool:
                
                thresholds_raw = rows_staircase['questMeanAtEndOfTrialsLoop'].dropna().values
                assert len(thresholds_raw) == 1, 'Error: more than 1 thresholds'
                
                thresholds_raw_log = thresholds_raw[0]
                
                thresholds_raw_deg = 10 ** thresholds_raw_log
                
                # Assign to left and right array
                if s == 0:
                    subj_right[subj, b - 2] = thresholds_raw_deg
                elif s == 1: 
                    subj_left[subj, b - 2] = thresholds_raw_deg

# %%
subj_thresholds = (subj_right + subj_left)/2
vernier = pd.DataFrame(subj_thresholds)
df_rsvp

# %%
df_rsvp.to_csv('df_rsvp.csv', index=False)

# %%
# Plot for subj_right_bouma
repeats = np.arange(1, subj_right.shape[1] + 1)

plt.figure(figsize=(10, 6))
for i, row in enumerate(subj_right):
    plt.plot(repeats, row, marker='o', label=f'Participant {i+1}')
plt.title('Right Vernier', fontsize = 16)
plt.xlabel('Repeats', fontsize = 14)
plt.ylabel('Threshold (deg)', fontsize = 14)
# plt.legend()
plt.yscale('log')
plt.ylim([0.005,100])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# Plot for subj_left_bouma
plt.figure(figsize=(10, 6))
for i, row in enumerate(subj_left):
    plt.plot(repeats, row, marker='o', label=f'Participant {i+1}')
plt.title('Left Vernier', fontsize = 16)
plt.xlabel('Repeats', fontsize = 14)
plt.ylabel('Threshold (deg)', fontsize = 14)
# plt.legend()
plt.yscale('log')
plt.ylim([0.005,100])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
# 1. Variance within individuals: Variance across the 6 runs for each participant
within_individual_variance = np.var(subj_right, axis=1, ddof=1)

# 2. Variance across individuals: Variance across 4 participants for each run
across_individuals_variance = np.var(subj_right, axis=0, ddof=1)

print(within_individual_variance)
print(across_individuals_variance)
# Out:
# [1.28674152e-03 5.33038737e-03 1.39969102e-04 1.60916646e+02
#  6.42842510e-05 2.12540564e+02 2.32177202e-03 3.51432407e-03
#  2.77880097e-05 6.24824509e-03 6.50872771e+00 1.05143518e-04
#  5.86483892e-05 6.13032997e-05 4.85359593e+00]
# [ 70.63662789 106.08566812  63.30166711  46.00959456  56.82395286
#  102.75068425]
